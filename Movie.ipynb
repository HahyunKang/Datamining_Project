# %% [markdown]
# <a href="https://colab.research.google.com/github/HahyunKang/Datamining_Project/blob/main/Movie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from ast import literal_eval
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# %matplotlib inline

# %%
movies = pd.read_csv("/content/drive/MyDrive/대학/3-2/DataMining/TeamProject/archive/movies_metadata.csv")

movies.head()
# Out:
# <ipython-input-2-333dfa7e0f8d>:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies = pd.read_csv("/content/drive/MyDrive/대학/3-2/DataMining/TeamProject/archive/movies_metadata.csv")
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
movies['genres'][0]
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
movies['genres'] = movies['genres'].fillna('[]').apply(literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# %%
keywords = pd.read_csv('/content/drive/MyDrive/대학/3-2/DataMining/TeamProject/archive/keywords.csv')

# %%
keywords.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
ratings = pd.read_csv('/content/drive/MyDrive/대학/3-2/DataMining/TeamProject/archive/ratings.csv')

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
average_ratings = ratings.groupby('movieId')['rating'].mean().reset_index()
average_ratings.rename(columns={'rating': 'average_rating'}, inplace=True)

# %%
average_ratings = average_ratings.sort_values('movieId')

average_ratings.set_index('movieId', inplace=True)

average_ratings.rename(columns={'movieId': 'id'}, inplace=True)

# %%
average_ratings.head()
# Out:
#          average_rating
# movieId
# 1              3.888157
# 2              3.236953
# 3              3.175550
# 4              2.875713
# 5              3.079565

# %%
movies['id'] = pd.to_numeric(movies['id'], errors='coerce')

movies = movies.dropna(subset=['id'])

# %%
movies['id'] = movies['id'].astype('int')
keywords['id'] = keywords['id'].astype('int')

movies = movies.merge(keywords, on='id')
movies = movies.merge(average_ratings, left_on='id', right_index=True)

movies.head()
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   False                                                NaN  65000000
# 5   False                                                NaN  60000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 14  False                                                NaN  98000000
#
#                               genres  \
# 0        [Animation, Comedy, Family]
# 1       [Adventure, Fantasy, Family]
# 5   [Action, Crime, Drama, Thriller]
# 9      [Adventure, Action, Thriller]
# 14               [Action, Adventure]
#
#                                         homepage    id    imdb_id  \
# 0           http://toystory.disney.com/toy-story   862  tt0114709
# 1                                            NaN  8844  tt0113497
# 5                                            NaN   949  tt0113277
# 9   http://www.mgm.com/view/movie/757/Goldeneye/   710  tt0113189
# 14                                           NaN  1408  tt0112760
#
#    original_language    original_title  \
# 0                 en         Toy Story
# 1                 en           Jumanji
# 5                 en              Heat
# 9                 en         GoldenEye
# 14                en  Cutthroat Island
#
#                                              overview  ... runtime  \
# 0   Led by Woody, Andy's toys live happily in his ...  ...    81.0
# 1   When siblings Judy and Peter discover an encha...  ...   104.0
# 5   Obsessive master thief, Neil McCauley leads a ...  ...   170.0
# 9   James Bond must unmask the mysterious head of ...  ...   130.0
# 14  Morgan Adams and her slave, William Shaw, are ...  ...   119.0
#
#                                      spoken_languages    status  \
# 0            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 5   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 9   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 14  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                               tagline             title  \
# 0                                                 NaN         Toy Story
# 1           Roll the dice and unleash the excitement!           Jumanji
# 5                            A Los Angeles Crime Saga              Heat
# 9                No limits. No fears. No substitutes.         GoldenEye
# 14  The Course Has Been Set. There Is No Turning B...  Cutthroat Island
#
#     video  vote_average vote_count  \
# 0   False           7.7     5415.0
# 1   False           6.9     2413.0
# 5   False           7.7     1886.0
# 9   False           6.6     1194.0
# 14  False           5.7      137.0
#
#                                              keywords average_rating
# 0   [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...       3.598930
# 1   [{'id': 10090, 'name': 'board game'}, {'id': 1...       3.760163
# 5   [{'id': 642, 'name': 'robbery'}, {'id': 703, '...       3.905544
# 9   [{'id': 701, 'name': 'cuba'}, {'id': 769, 'nam...       2.740334
# 14  [{'id': 911, 'name': 'exotic island'}, {'id': ...       3.710181
#
# [5 rows x 26 columns]

# %%
movies["keywords"][0]
# Out:
# "[{'id': 931, 'name': 'jealousy'}, {'id': 4290, 'name': 'toy'}, {'id': 5202, 'name': 'boy'}, {'id': 6054, 'name': 'friendship'}, {'id': 9713, 'name': 'friends'}, {'id': 9823, 'name': 'rivalry'}, {'id': 165503, 'name': 'boy next door'}, {'id': 170722, 'name': 'new toy'}, {'id': 187065, 'name': 'toy comes to life'}]"

# %%
movies["keywords"] = movies["keywords"].apply(literal_eval)

# %%
def generate_list(x):
    if isinstance(x, list):
        names = [i['name'] for i in x]
        if len(names) > 10:
            names = names[:10]
        return names
    return []

movies['keywords'] = movies['keywords'].apply(generate_list)
movies['genres'] = movies['genres'].apply(lambda x: x[:10])

movies[['title', 'keywords', 'genres', 'average_rating']].head()
# Out:
#                title                                           keywords  \
# 0          Toy Story  [jealousy, toy, boy, friendship, friends, riva...
# 1            Jumanji  [board game, disappearance, based on children'...
# 5               Heat  [robbery, detective, bank, obsession, chase, s...
# 9          GoldenEye  [cuba, falsely accused, secret identity, compu...
# 14  Cutthroat Island  [exotic island, treasure, map, ship, scalp, pi...
#
#                               genres  average_rating
# 0        [Animation, Comedy, Family]        3.598930
# 1       [Adventure, Fantasy, Family]        3.760163
# 5   [Action, Crime, Drama, Thriller]        3.905544
# 9      [Adventure, Action, Thriller]        2.740334
# 14               [Action, Adventure]        3.710181

# %%
def normalize_text(x):
  if isinstance(x, list):
        return [elem.lower().replace(' ', '') for elem in x]
  return x.lower().replace(' ', '') if isinstance(x, str) else ''

for feature in ['genres', 'keywords']:
    movies[feature] = movies[feature].apply(normalize_text)

# %%
movies.head()
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   False                                                NaN  65000000
# 5   False                                                NaN  60000000
# 9   False  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 14  False                                                NaN  98000000
#
#                               genres  \
# 0        [animation, comedy, family]
# 1       [adventure, fantasy, family]
# 5   [action, crime, drama, thriller]
# 9      [adventure, action, thriller]
# 14               [action, adventure]
#
#                                         homepage    id    imdb_id  \
# 0           http://toystory.disney.com/toy-story   862  tt0114709
# 1                                            NaN  8844  tt0113497
# 5                                            NaN   949  tt0113277
# 9   http://www.mgm.com/view/movie/757/Goldeneye/   710  tt0113189
# 14                                           NaN  1408  tt0112760
#
#    original_language    original_title  \
# 0                 en         Toy Story
# 1                 en           Jumanji
# 5                 en              Heat
# 9                 en         GoldenEye
# 14                en  Cutthroat Island
#
#                                              overview  ... runtime  \
# 0   Led by Woody, Andy's toys live happily in his ...  ...    81.0
# 1   When siblings Judy and Peter discover an encha...  ...   104.0
# 5   Obsessive master thief, Neil McCauley leads a ...  ...   170.0
# 9   James Bond must unmask the mysterious head of ...  ...   130.0
# 14  Morgan Adams and her slave, William Shaw, are ...  ...   119.0
#
#                                      spoken_languages    status  \
# 0            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 5   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 9   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 14  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                               tagline             title  \
# 0                                                 NaN         Toy Story
# 1           Roll the dice and unleash the excitement!           Jumanji
# 5                            A Los Angeles Crime Saga              Heat
# 9                No limits. No fears. No substitutes.         GoldenEye
# 14  The Course Has Been Set. There Is No Turning B...  Cutthroat Island
#
#     video  vote_average vote_count  \
# 0   False           7.7     5415.0
# 1   False           6.9     2413.0
# 5   False           7.7     1886.0
# 9   False           6.6     1194.0
# 14  False           5.7      137.0
#
#                                              keywords average_rating
# 0   [jealousy, toy, boy, friendship, friends, riva...       3.598930
# 1   [boardgame, disappearance, basedonchildren'sbo...       3.760163
# 5   [robbery, detective, bank, obsession, chase, s...       3.905544
# 9   [cuba, falselyaccused, secretidentity, compute...       2.740334
# 14  [exoticisland, treasure, map, ship, scalp, pir...       3.710181
#
# [5 rows x 26 columns]

# %%
def movie_features(x):
    return (x["title"] + " " +
            " ".join(x['genres']) + " " +
            x['overview'] + " " +
            " ".join(x['keywords']) + " " +
            str(x['average_rating']))

movies['overview'] = movies['overview'].fillna('')
movies['title'] = movies['title'].fillna('')
movies['average_rating'] = movies['average_rating'].fillna(0)

movies['movie_features'] = movies.apply(movie_features, axis=1)

# %%
movies.loc[movies['title']=="The Matrix",'movie_features'].values
# Out:
# array(['The Matrix action sciencefiction Set in the 22nd century, The Matrix tells the story of a computer hacker who joins a group of underground insurgents fighting the vast and powerful computers who now rule the earth. savingtheworld artificialintelligence manvsmachine philosophy prophecy martialarts selfsacrifice fight insurgence virtualreality 2.9557877813504825'],
#       dtype=object)
